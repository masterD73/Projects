# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
X, y = make_blobs() # make the blobs: y contains the cluster IDs, but we
# will not use them; that's what we want to predict
k = 5
kmeans = KMeans(n_clusters=k, random_state=42, n_init=12)
y_pred = kmeans.fit_predict(X)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], c=y_pred)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 9.04659256, -4.22920462],
#        [-7.20462473,  6.26955214],
#        [ 7.01980942, -1.84079949],
#        [ 8.86032518, -2.20071078],
#        [ 9.98927179, -5.90588035]])
